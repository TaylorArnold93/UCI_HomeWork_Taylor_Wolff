# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Calculating the various columns 
total_schools = school_data_complete["school_name"].nunique()
total_students = school_data_complete["student_name"].count()
total_budget = school_data_complete["budget"].unique().sum()
math_score_avg = school_data_complete["math_score"].mean()
reading_score_avg = school_data_complete["reading_score"].mean()

# Calculating the percentage of students various subjects with a passing score
pass_rate_math = 100*len(school_data_complete[school_data_complete["math_score"]>=70]) / total_students
pass_rate_reading = 100*len(school_data_complete[school_data_complete["reading_score"]>=70]) / total_students
overall_rate = (math_score_avg + reading_score_avg) / 2

# dataframe of the District Summary dictionary 
district_summary = pd.DataFrame({"Total Schools": [total_schools],
                              "Total Students": [total_students],
                              "Total Budget": [total_budget],
                              "Average Math Score": [math_score_avg],
                              "Average Reading Score": [reading_score_avg], 
                              "% Passing Math": [pass_rate_math],
                              "% Passing Reading": [pass_rate_reading],
                              "% Overall Passing Rate": [overall_rate]})
# Cleaning up the format of the district summary

district_summary = pd.DataFrame(district_summary)
district_summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       74.980853          85.805463
#
#    % Overall Passing Rate
# 0               80.431606

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# Grouped our complete data frame by school name 
school_summary = school_data_complete.groupby(['school_name'])
school_type = school_data.set_index('school_name')['type']
total_student = school_summary['Student ID'].count()
total_budget = school_data.set_index('school_name')['budget']
budget_per_student = total_budget / total_student
avg_math_score = school_summary['math_score'].mean()
avg_reading_score = school_summary['reading_score'].mean()
passing_math_percent = school_data_complete[school_data_complete['math_score'] >= 70].groupby('school_name')['Student ID'].count()/total_student*100
passing_read_percent = school_data_complete[school_data_complete['reading_score'] >= 70].groupby('school_name')['Student ID'].count()/total_student*100
overall_passing_percent = school_data_complete[(school_data_complete['reading_score'] >= 70) & (school_data_complete['math_score'] >= 70)].groupby('school_name')['Student ID'].count()/total_student*100

# Create a dataframe to hold the above results

school_summary = pd.DataFrame({
    "School Type": school_type,
    "Total Students": total_student,
    "Per Student Budget": budget_per_student,
    "Total Budget": total_budget,
    "Average Math Score": avg_math_score,
    "Average Reading Score": avg_reading_score,
    '% Passing Math': passing_math_percent,
    '% Passing Reading': passing_read_percent,
    "% Overall Passing Rate": overall_passing_percent
})

school_summary = school_summary[['School Type', 
                          'Total Students', 
                          'Total Budget', 
                          'Per Student Budget', 
                          'Average Math Score', 
                          'Average Reading Score',
                          '% Passing Math',
                          '% Passing Reading',
                          '% Overall Passing Rate']]


school_summary.style.format({'Total Students': '{:}',
                          "Total School Budget": "${:,.2f}",
                          "Per Student Budget": "${:.2f}",
                          'Average Math Score': "{:6f}", 
                          'Average Reading Score': "{:6f}", 
                          "% Passing Math": "{:6f}", 
                          "% Passing Reading": "{:6f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_24408bd0_091f_11eb_a206_08d23efd18a2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >School Type</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total Budget</th>        <th class="col_heading level0 col3" >Per Student Budget</th>        <th class="col_heading level0 col4" >Average Math Score</th>        <th class="col_heading level0 col5" >Average Reading Score</th>        <th class="col_heading level0 col6" >% Passing Math</th>        <th class="col_heading level0 col7" >% Passing Reading</th>        <th class="col_heading level0 col8" >% Overall Passing Rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_24408bd0_091f_11eb_a206_08d23efd18a2level0_row0" class="row_heading level0 row0" >Bailey High School</th>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row0_col0" class="data row0 col0" >District</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row0_col1" class="data row0 col1" >4976</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row0_col2" class="data row0 col2" >3124928</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row0_col3" class="data row0 col3" >$628.00</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row0_col4" class="data row0 col4" >77.048432</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row0_col5" class="data row0 col5" >81.033963</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row0_col6" class="data row0 col6" >66.680064</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row0_col7" class="data row0 col7" >81.933280</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row0_col8" class="data row0 col8" >54.642283</td>
#             </tr>
#             <tr>
#                         <th id="T_24408bd0_091f_11eb_a206_08d23efd18a2level0_row1" class="row_heading level0 row1" >Cabrera High School</th>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row1_col0" class="data row1 col0" >Charter</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row1_col1" class="data row1 col1" >1858</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row1_col2" class="data row1 col2" >1081356</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row1_col3" class="data row1 col3" >$582.00</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row1_col4" class="data row1 col4" >83.061895</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row1_col5" class="data row1 col5" >83.975780</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row1_col6" class="data row1 col6" >94.133477</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row1_col7" class="data row1 col7" >97.039828</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row1_col8" class="data row1 col8" >91.334769</td>
#             </tr>
#             <tr>
#                         <th id="T_24408bd0_091f_11eb_a206_08d23efd18a2level0_row2" class="row_heading level0 row2" >Figueroa High School</th>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row2_col0" class="data row2 col0" >District</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row2_col1" class="data row2 col1" >2949</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row2_col2" class="data row2 col2" >1884411</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row2_col3" class="data row2 col3" >$639.00</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row2_col4" class="data row2 col4" >76.711767</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row2_col5" class="data row2 col5" >81.158020</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row2_col6" class="data row2 col6" >65.988471</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row2_col7" class="data row2 col7" >80.739234</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row2_col8" class="data row2 col8" >53.204476</td>
#             </tr>
#             <tr>
#                         <th id="T_24408bd0_091f_11eb_a206_08d23efd18a2level0_row3" class="row_heading level0 row3" >Ford High School</th>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row3_col0" class="data row3 col0" >District</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row3_col1" class="data row3 col1" >2739</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row3_col2" class="data row3 col2" >1763916</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row3_col3" class="data row3 col3" >$644.00</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row3_col4" class="data row3 col4" >77.102592</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row3_col5" class="data row3 col5" >80.746258</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row3_col6" class="data row3 col6" >68.309602</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row3_col7" class="data row3 col7" >79.299014</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row3_col8" class="data row3 col8" >54.289887</td>
#             </tr>
#             <tr>
#                         <th id="T_24408bd0_091f_11eb_a206_08d23efd18a2level0_row4" class="row_heading level0 row4" >Griffin High School</th>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row4_col0" class="data row4 col0" >Charter</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row4_col1" class="data row4 col1" >1468</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row4_col2" class="data row4 col2" >917500</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row4_col3" class="data row4 col3" >$625.00</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row4_col4" class="data row4 col4" >83.351499</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row4_col5" class="data row4 col5" >83.816757</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row4_col6" class="data row4 col6" >93.392371</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row4_col7" class="data row4 col7" >97.138965</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row4_col8" class="data row4 col8" >90.599455</td>
#             </tr>
#             <tr>
#                         <th id="T_24408bd0_091f_11eb_a206_08d23efd18a2level0_row5" class="row_heading level0 row5" >Hernandez High School</th>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row5_col0" class="data row5 col0" >District</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row5_col1" class="data row5 col1" >4635</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row5_col2" class="data row5 col2" >3022020</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row5_col3" class="data row5 col3" >$652.00</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row5_col4" class="data row5 col4" >77.289752</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row5_col5" class="data row5 col5" >80.934412</td>
#                         <td id="T_24408bd0_091f_11eb_a206_08d23efd18a2row5_col6" class="data row5 col6" >66.752967</td>

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
top_performing_schools = school_summary.sort_values("% Overall Passing Rate", ascending = False)
top_performing_schools.head(5)
# Out:
#                     School Type  Total Students  Total Budget  \
# Cabrera High School     Charter            1858       1081356
# Thomas High School      Charter            1635       1043130
# Griffin High School     Charter            1468        917500
# Wilson High School      Charter            2283       1319574
# Pena High School        Charter             962        585858
#
#                      Per Student Budget  Average Math Score  \
# Cabrera High School               582.0           83.061895
# Thomas High School                638.0           83.418349
# Griffin High School               625.0           83.351499
# Wilson High School                578.0           83.274201
# Pena High School                  609.0           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# Thomas High School               83.848930       93.272171          97.308869
# Griffin High School              83.816757       93.392371          97.138965
# Wilson High School               83.989488       93.867718          96.539641
# Pena High School                 84.044699       94.594595          95.945946
#
#                      % Overall Passing Rate
# Cabrera High School               91.334769
# Thomas High School                90.948012
# Griffin High School               90.599455
# Wilson High School                90.582567
# Pena High School                  90.540541

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
bottom_performing_schools = school_summary.sort_values("% Overall Passing Rate")
bottom_performing_schools.head(5)
# Out:
#                       School Type  Total Students  Total Budget  \
# Rodriguez High School    District            3999       2547363
# Figueroa High School     District            2949       1884411
# Huang High School        District            2917       1910635
# Hernandez High School    District            4635       3022020
# Johnson High School      District            4761       3094650
#
#                        Per Student Budget  Average Math Score  \
# Rodriguez High School               637.0           76.842711
# Figueroa High School                639.0           76.711767
# Huang High School                   655.0           76.629414
# Hernandez High School               652.0           77.289752
# Johnson High School                 650.0           77.072464
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# Figueroa High School               81.158020       65.988471
# Huang High School                  81.182722       65.683922
# Hernandez High School              80.934412       66.752967
# Johnson High School                80.966394       66.057551
#
#                        % Passing Reading  % Overall Passing Rate
# Rodriguez High School          80.220055               52.988247
# Figueroa High School           80.739234               53.204476
# Huang High School              81.316421               53.513884
# Hernandez High School          80.862999               53.527508
# Johnson High School            81.222432               53.539172

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# Calculating the Math Scores by Grade 
avg_math_9th = school_data_complete[school_data_complete['grade']=='9th'].groupby('school_name')['math_score'].mean()
avg_math_10th = school_data_complete[school_data_complete['grade']=='10th'].groupby('school_name')['math_score'].mean()
avg_math_11th = school_data_complete[school_data_complete['grade']=='11th'].groupby('school_name')['math_score'].mean()
avg_math_12th = school_data_complete[school_data_complete['grade']=='12th'].groupby('school_name')['math_score'].mean()

# Created DataFrame by using data above (Math Scores by Grade)
grade_math_score={
    '9th':avg_math_9th,
    '10th':avg_math_10th,
    '11th':avg_math_11th,
    '12th':avg_math_12th,
    }

math_score_by_grade = pd.DataFrame(grade_math_score)
math_score_by_grade.index.name = None
math_score_by_grade.head(20)
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# Wilson High School     83.085578  83.724422  83.195326  83.035794
# Wright High School     83.264706  84.010288  83.836782  83.644986

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
# Calculating the Reading Scores by Grade 
avg_reading_9th = school_data_complete[school_data_complete['grade']=='9th'].groupby('school_name')['reading_score'].mean()
avg_reading_10th = school_data_complete[school_data_complete['grade']=='10th'].groupby('school_name')['reading_score'].mean()
avg_reading_11th = school_data_complete[school_data_complete['grade']=='11th'].groupby('school_name')['reading_score'].mean()
avg_reading_12th = school_data_complete[school_data_complete['grade']=='12th'].groupby('school_name')['reading_score'].mean()

# Created DataFrame by using data above (Reading Scores by Grade)
reading_grade_score={
    '9th':avg_reading_9th,
    '10th':avg_reading_10th,
    '11th':avg_reading_11th,
    '12th':avg_reading_12th,
    }

reading_score_by_grade = pd.DataFrame(reading_grade_score)
reading_score_by_grade.index.name = None
reading_score_by_grade.head(20)
# Out:
#                              9th       10th       11th       12th
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# Wilson High School     83.939778  84.021452  83.764608  84.317673
# Wright High School     83.833333  83.812757  84.156322  84.073171

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Spending Ranges per Students 
spending_ranges = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

# calculate the various columns
school_data_complete['avg_budget'] = school_data_complete['budget'] / school_data_complete['size']
school_data_complete['School Spending'] = pd.cut(school_data_complete["avg_budget"], spending_ranges, labels=group_names)
spending_group = school_data_complete.groupby('School Spending')
spending_total_student = spending_group['Student ID'].count()
spending_math_avg = spending_group['math_score'].mean()
spending_reading_avg = spending_group['reading_score'].mean()
spending_math_pass_number = school_data_complete[school_data_complete['math_score']>=70].groupby('School Spending')['math_score'].count()
spending_math_pass_rate = 100 * spending_math_pass_number / spending_total_student
spending_read_pass_number = school_data_complete[school_data_complete['reading_score']>=70].groupby('School Spending')['reading_score'].count()
spending_read_pass_rate = 100 * spending_read_pass_number / spending_total_student

school_spending_df = pd.DataFrame({
        "Average Math Score": spending_math_avg,
        "Average Reading Score": spending_reading_avg,
        "% Passing Math": spending_math_pass_rate,
        "% Passing Reading": spending_read_pass_rate,
        "% Overall Passing Rate": (spending_math_pass_rate + spending_read_pass_rate) / 2
    },
    columns=["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing Rate"])

school_spending_df
# Out:
#                  Average Math Score  Average Reading Score  % Passing Math  \
# School Spending
# <$585                     83.363065              83.964039       93.702889
# $585-615                  83.529196              83.838414       94.124128
# $615-645                  78.061635              81.434088       71.400428
# $645-675                  77.049297              81.005604       66.230813
#
#                  % Passing Reading  % Overall Passing Rate
# School Spending
# <$585                    96.686558               95.194724
# $585-615                 95.886889               95.005509
# $615-645                 83.614770               77.507599
# $645-675                 81.109397               73.670105

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# School Size sample
size_ranges = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]
               
# calculate the various columns
school_data_complete['School Size'] = pd.cut(school_data_complete["size"], size_ranges, labels=group_names)
school_size_group = school_data_complete.groupby('School Size')
school_size_total_student = school_size_group['Student ID'].count()
school_size_math_avg = school_size_group['math_score'].mean()
school_size_reading_avg = school_size_group['reading_score'].mean()
school_size_math_pass_number = school_data_complete[school_data_complete['math_score']>=70].groupby('School Size')['math_score'].count()
school_size_math_pass_rate = 100 * school_size_math_pass_number / school_size_total_student
school_size_read_pass_number = school_data_complete[school_data_complete['reading_score']>=70].groupby('School Size')['reading_score'].count()
school_size_read_pass_rate = 100 * school_size_read_pass_number / school_size_total_student

school_size_df = pd.DataFrame({
        "Average Math Score": school_size_math_avg,
        "Average Reading Score": school_size_reading_avg,
        "% Passing Math": school_size_math_pass_rate,
        "% Passing Reading": school_size_read_pass_rate,
        "% Overall Passing Rate": (school_size_math_pass_rate + school_size_read_pass_rate) / 2
    },
    columns=["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing Rate"])

school_size_df
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.828654              83.974082       93.952484
# Medium (1000-2000)           83.372682              83.867989       93.616522
# Large (2000-5000)            77.477597              81.198674       68.652380
#
#                     % Passing Reading  % Overall Passing Rate
# School Size
# Small (<1000)               96.040317               94.996400
# Medium (1000-2000)          96.773058               95.194790
# Large (2000-5000)           82.125158               75.388769

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# calculate the various columns
school_score_type_group = school_data_complete.groupby('type')
school_score_type_total_student = school_score_type_group['Student ID'].count()
school_score_type_math_avg = school_score_type_group['math_score'].mean()
school_score_type_reading_avg = school_score_type_group['reading_score'].mean()
school_score_type_math_pass_number = school_data_complete[school_data_complete['math_score']>=70].groupby('type')['math_score'].count()
school_score_type_math_pass_rate = 100 * school_score_type_math_pass_number / school_score_type_total_student
school_score_type_read_pass_number = school_data_complete[school_data_complete['reading_score']>=70].groupby('type')['reading_score'].count()
school_score_type_read_pass_rate = 100 * school_score_type_read_pass_number / school_score_type_total_student

school_score_type_df = pd.DataFrame({
        "Average Math Score": school_score_type_math_avg,
        "Average Reading Score": school_score_type_reading_avg,
        "% Passing Math": school_score_type_math_pass_rate,
        "% Passing Reading": school_score_type_read_pass_rate,
        "% Overall Passing Rate": (school_score_type_math_pass_rate + school_score_type_read_pass_rate) / 2
    },
    columns=["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing Rate"])

school_score_type_df
# Out:
#           Average Math Score  Average Reading Score  % Passing Math  \
# type
# Charter            83.406183              83.902821       93.701821
# District           76.987026              80.962485       66.518387
#
#           % Passing Reading  % Overall Passing Rate
# type
# Charter           96.645891               95.173856
# District          80.905249               73.711818

# %%
References
Styling — pandas 1.1.3 documentation. (n.d.). Pandas - Python Data Analysis Library.
https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html
